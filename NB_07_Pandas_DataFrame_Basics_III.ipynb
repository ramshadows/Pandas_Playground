# %% [markdown]
# # Sorting DataFrames with sort_index() and sort_values()

# %%
import pandas as pd

# %%
titanic = pd.read_csv("Data1/Video_Lecture_NBs/titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age.sort_values()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 891, dtype: float64

# %%
titanic.sort_values(by = "age", ascending=True) #Atrenative method
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = ["pclass", "sex", "age"], ascending=True, inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 297         0       1  female   2.0      1      2  151.5500        S    C
# 435         1       1  female  14.0      1      2  120.0000        S    B
# 689         1       1  female  15.0      0      1  211.3375        S    B
# 329         1       1  female  16.0      0      1   57.9792        C    B
# 504         1       1  female  16.0      0      0   86.5000        S    B
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 837         0       3    male   NaN      0      0    8.0500        S  NaN
# 846         0       3    male   NaN      8      2   69.5500        S  NaN
# 859         0       3    male   NaN      0      0    7.2292        C  NaN
# 868         0       3    male   NaN      0      0    9.5000        S  NaN
# 878         0       3    male   NaN      0      0    7.8958        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = ["pclass", "sex", "age"], ascending=[True, True, False], inplace=True)

# %%
titanic.head(50)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 275         1       1  female  63.0      1      0   77.9583        S    D
# 829         1       1  female  62.0      0      0   80.0000      NaN    B
# 366         1       1  female  60.0      1      0   75.2500        C    D
# 11          1       1  female  58.0      0      0   26.5500        S    C
# 195         1       1  female  58.0      0      0  146.5208        C    B
# 268         1       1  female  58.0      0      1  153.4625        S    C
# 879         1       1  female  56.0      0      1   83.1583        C    C
# 496         1       1  female  54.0      1      0   78.2667        C    D
# 513         1       1  female  54.0      1      0   59.4000        C  NaN
# 571         1       1  female  53.0      2      0   51.4792        S    C
# 591         1       1  female  52.0      1      0   78.2667        C    D
# 820         1       1  female  52.0      1      1   93.5000        S    B
# ...

# %% [markdown]
# # Sorting by index

# %%
titanic.sort_index(ascending=True, inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# # Ranking DataFrames with rank()

# %%
sales = pd.Series([134, 567, 783, 112, 230], index=["Mon", "Tue", "Wed", "Thu", "Fri"], name = "Sales")

# %%
sales
# Out:
# Mon    134
# Tue    567
# Wed    783
# Thu    112
# Fri    230
# Name: Sales, dtype: int64

# %%
sales.sort_values(ascending=True)
# Out:
# Thu    112
# Mon    134
# Fri    230
# Tue    567
# Wed    783
# Name: Sales, dtype: int64

# %%
sales.rank()
# Out:
# Mon    2.0
# Tue    4.0
# Wed    5.0
# Thu    1.0
# Fri    3.0
# Name: Sales, dtype: float64

# %%
sales.rank(ascending=False).sort_values()
# Out:
# Wed    1.0
# Tue    2.0
# Fri    3.0
# Mon    4.0
# Thu    5.0
# Name: Sales, dtype: float64

# %%
sales.rank(ascending=False, method="min").sort_values(ascending=True)
# Out:
# Wed    1.0
# Tue    2.0
# Fri    3.0
# Mon    4.0
# Thu    5.0
# Name: Sales, dtype: float64

# %%
sales.rank(ascending=False, method="min", pct=True).sort_values(ascending=True)
# Out:
# Wed    0.2
# Tue    0.4
# Fri    0.6
# Mon    0.8
# Thu    1.0
# Name: Sales, dtype: float64

# %%
titanic.fare.rank(ascending=False)
# Out:
# 0      815.0
# 1      103.0
# 2      659.5
# 3      144.0
# 4      628.0
#        ...
# 886    484.5
# 887    237.5
# 888    345.5
# 889    237.5
# 890    768.5
# Name: fare, Length: 891, dtype: float64

# %%
titanic["fare_rank"] = titanic.fare.rank(ascending = False, method = "min")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    fare_rank
# 0      809.0
# 1      103.0
# 2      651.0
# 3      142.0
# 4      607.0

# %%
titanic.sort_values("fare", ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 27          0       1    male  19.0      3      2  263.0000        S    C
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 633         0       1    male   NaN      0      0    0.0000        S  NaN
# 413         0       2    male   NaN      0      0    0.0000        S  NaN
# 822         0       1    male  38.0      0      0    0.0000        S  NaN
# 732         0       2    male   NaN      0      0    0.0000        S  NaN
# 674         0       2    male   NaN      0      0    0.0000        S  NaN
#
#      fare_rank
# 258        1.0
# 737        1.0
# 679        1.0
# ...

# %% [markdown]
# # nunique(), nlargest() and nsmallest() with DataFrames

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      fare_rank
# 0        809.0
# 1        103.0
# 2        651.0
# 3        142.0
# ...

# %%
titanic.nunique()
# Out:
# survived       2
# pclass         3
# sex            2
# age           88
# sibsp          7
# parch          7
# fare         248
# embarked       3
# deck           7
# fare_rank    248
# dtype: int64

# %%
titanic.nunique(axis=0)
# Out:
# survived       2
# pclass         3
# sex            2
# age           88
# sibsp          7
# parch          7
# fare         248
# embarked       3
# deck           7
# fare_rank    248
# dtype: int64

# %%
titanic.nunique(axis=0, dropna=False)
# Out:
# survived       2
# pclass         3
# sex            2
# age           89
# sibsp          7
# parch          7
# fare         248
# embarked       4
# deck           8
# fare_rank    248
# dtype: int64

# %%
titanic.nlargest(n=5, columns="fare")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 27          0       1    male  19.0      3      2  263.0000        S    C
# 88          1       1  female  23.0      3      2  263.0000        S    C
#
#      fare_rank
# 258        1.0
# 679        1.0
# 737        1.0
# 27         4.0
# 88         4.0

# %%
titanic.sort_values("fare", ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 27          0       1    male  19.0      3      2  263.0000        S    C
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 633         0       1    male   NaN      0      0    0.0000        S  NaN
# 413         0       2    male   NaN      0      0    0.0000        S  NaN
# 822         0       1    male  38.0      0      0    0.0000        S  NaN
# 732         0       2    male   NaN      0      0    0.0000        S  NaN
# 674         0       2    male   NaN      0      0    0.0000        S  NaN
#
#      fare_rank
# 258        1.0
# 737        1.0
# 679        1.0
# ...

# %%
titanic.nsmallest(n=2, columns="age")
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck  \
# 803         1       3  male  0.42      0      1   8.5167        C  NaN
# 755         1       2  male  0.67      1      1  14.5000        S  NaN
#
#      fare_rank
# 803      598.0
# 755      435.0

# %%
titanic.sort_values("age", ascending=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
#      fare_rank
# 803      598.0
# 755      435.0
# 644      381.0
# 469      381.0
# ...

# %%
titanic.loc[titanic.age.idxmin()]
# Out:
# survived          1
# pclass            3
# sex            male
# age            0.42
# sibsp             0
# parch             1
# fare         8.5167
# embarked          C
# deck            NaN
# fare_rank       598
# Name: 803, dtype: object

# %% [markdown]
# # Summary Statistics and Accumulution of numeric values in a DataFrame

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#         fare_rank
# count  891.000000
# mean   439.961841
# std    254.525014
# min      1.000000
# 25%    223.000000
# 50%    445.000000
# 75%    660.000000
# max    877.000000

# %%
titanic.count(axis=0)
# Out:
# survived     891
# pclass       891
# sex          891
# age          714
# sibsp        891
# parch        891
# fare         891
# embarked     889
# deck         203
# fare_rank    891
# dtype: int64

# %%
titanic.count(axis=1)
# Out:
# 0       9
# 1      10
# 2       9
# 3      10
# 4       9
#        ..
# 886     9
# 887    10
# 888     8
# 889    10
# 890     9
# Length: 891, dtype: int64

# %%
titanic.mean(axis = 1)
# Out:
# 0      120.321429
# 1       30.754757
# 2       98.417857
# 3       33.300000
# 4       93.292857
#           ...
# 886     72.285714
# 887     40.857143
# 888     62.408333
# 889     41.857143
# 890    113.535714
# Length: 891, dtype: float64

# %%
titanic.mean(axis = 0)
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# fare_rank    439.961841
# dtype: float64

# %%
titanic.sum(axis = 0)
# Out:
# survived                                                   342
# pclass                                                    2057
# sex          malefemalefemalefemalemalemalemalemalefemalefe...
# age                                                    21205.2
# sibsp                                                      466
# parch                                                      340
# fare                                                   28693.9
# fare_rank                                               392006
# dtype: object

# %%
titanic.sum(axis = 0, numeric_only=True)
# Out:
# survived        342.0000
# pclass         2057.0000
# age           21205.1700
# sibsp           466.0000
# parch           340.0000
# fare          28693.9493
# fare_rank    392006.0000
# dtype: float64

# %%
titanic.sum(axis = 0, skipna=True, numeric_only=True)
# Out:
# survived        342.0000
# pclass         2057.0000
# age           21205.1700
# sibsp           466.0000
# parch           340.0000
# fare          28693.9493
# fare_rank    392006.0000
# dtype: float64

# %%
titanic.fare.cumsum(axis = 0)
# Out:
# 0          7.2500
# 1         78.5333
# 2         86.4583
# 3        139.5583
# 4        147.6083
#           ...
# 886    28602.7493
# 887    28632.7493
# 888    28656.1993
# 889    28686.1993
# 890    28693.9493
# Name: fare, Length: 891, dtype: float64

# %%
titanic.cumsum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-9545322b6b7f> in <module>
# ----> 1 titanic.cumsum()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in cum_func(self, axis, skipna, *args, **kwargs)
#   11329             return result.T if hasattr(result, "T") else result
#   11330
# > 11331         result = self._data.apply(na_accum_func)
#   11332
#   11333         d = self._construct_axes_dict()
#
# ...

# %%
titanic.corr()

# %%
titanic.survived.corr(titanic.pclass)#Correlation between two columns

# %% [markdown]
# # The agg() Method

# %%
titanic.head()

# %%
titanic.mean()

# %%
titanic.agg("mean")

# %%
titanic.agg(["mean", "std", "max", "min", "median"])

# %%
titanic.agg({"survived" : "mean", "age" : ["min", "max"]})

# %% [markdown]
# # User defined functions with apply() and applymap()

# %%
sales = pd.read_csv("Data1/Video_Lecture_NBs/sales.csv", index_col = 0)

# %%
sales

# %%
sales.info()

# %%
sales.min(axis = 0)

# %%
sales.min(axis = 1)

# %%
def range(series):
    return series.max() - series.min()

# %%
sales.apply(range, axis=0)

# %%
sales.apply(range, axis=1)

# %%
sales.apply(lambda series: series.max() - series.min(), axis=0)

# %%
summer = pd.read_csv("Data1/Video_Lecture_NBs/summer.csv")

# %% [raw]
# summer.head()

# %%
summer.Athlete.apply(lambda x: x[0])

# %%
summer.Athlete.map(lambda x: x[0])

# %%
summer.iloc[:, 1:3]

# %%
summer.iloc[:, 1:3].applymap(lambda x: x[0])

# %%
sales

# %% [markdown]
# ## Question: Let assume that there is a daily profit margin of 40% and a fixed cost of 5 that must be deducted from every sales man

# %%
sales * 0.4 - 5

# %%
sales.applymap(lambda x: x * 0.4 - 5)

# %% [markdown]
# # Hierachical Indexing / Multi-Indexing

# %%
titanic

# %%
titanic_1 = titanic.iloc[:50, :].copy()

# %%
titanic_1

# %%
titanic_1.reset_index(inplace=True)

# %%
titanic_1.set_index("pclass")

# %%
titanic_1.set_index(["pclass", "sex"], inplace = True) #Setting multi-index ie pclass(Outer index) and sex(inner index)

# %%
titanic_1.sort_index()

# %% [markdown]
# # Swapping multi-indexes with swaplevel() method

# %%
titanic_1.swaplevel().sort_index()

# %%
titanic_1.reset_index(inplace=True)

# %%
titanic_1

# %% [markdown]
# # Slicing and Indexing Multi-Indexed DataFrames

# %%
titanic_1.set_index(["pclass", "sex"], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-fae20867e9f3> in <module>
# ----> 1 titanic_1.set_index(["pclass", "sex"], inplace = True)
#
# NameError: name 'titanic_1' is not defined

# %%
titanic_1.sort_index(ascending=True)

# %%
titanic_1.loc[1]

# %%
titanic_1.loc[[1,2]].sort_index()

# %%
titanic_1.loc[:2]

# %%
titanic_1.loc[(1, "female")]

# %%
titanic_1.loc[(1, "female"), ["age"]]

# %%
titanic_1.loc[(1, "female"), ["age", "fare"]]

# %%
titanic_1.loc[([1,2], "female"), ["age", "fare"]].sort_index()

# %%
titanic_1.loc[([1,2], "female"), :].sort_index()

# %%
titanic_1.sort_index(inplace = True)

# %%
titanic_1

# %%
titanic_1

# %%
titanic_1.loc[(slice(None), slice("female")), :] #Select all female passengers in all pclass

# %%
titanic_1.loc[(slice(1), slice("female")), :] #Select all female passengers in  pclass 1

# %%
titanic_1.loc[(slice(2,2), slice("female")), :] #Select all female passengers in  pclass 2

# %%
titanic_1.loc[(slice(3,3), slice("female")), :] #Select all female passengers in  pclass 3

# %%
titanic_1.loc[(slice(2,2), slice("male","male")), :] #Select all male passengers in  pclass 2

# %%
titanic_1.loc[(slice(3,3), slice("male","male")), :] #Select all male passengers in  pclass 3

# %%
titanic_1.loc[(slice(2,3), slice("male","male")), :] #Select all male passengers in  pclass 2 & 3

# %%
titanic_1.loc[(slice(1,3), slice("male","male")), :] #Select all male passengers in  pclass 1 & 3

# %% [markdown]
# # String Operations on Pandas

# %%
summer = pd.read_csv("Data1/Video_Lecture_NBs/summer.csv")

# %% [raw]
# summer

# %%
names = summer.loc[:9, "Athlete"].copy()

# %%
names

# %%
names[0]

# %%
type(names[0])

# %%
names[0].lower()

# %%
names.str.lower()#Converts all to lower

# %%
names.str.title()

# %%
summer.Event

# %%
summer.Event.str.split(" ")

# %%
summer.Event.str.split(" ", n = 1)

# %%
summer.Event.str.split(" ", n = 2)

# %%
summer.Event.str.split(" ", n = 2, expand=True)

# %%
summer.Event.str.contains("100M")

# %%
summer[summer.Event.str.contains("100M")]
