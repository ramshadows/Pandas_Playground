# %%
import numpy as np
import pandas as pd

from collections import Counter

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
titanic = pd.read_csv("Data1/Video_Lecture_NBs/titanic.csv")

# %%
display(titanic)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
titanic.head(15) #First 15 rows
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
titanic.tail(15) #Last 15 rows
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 876         0       3    male  20.0      0      0   9.8458        S  NaN
# 877         0       3    male  19.0      0      0   7.8958        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# ...

# %% [markdown]
# # First Data Inspection

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include = 'O') #Descibes only columns with object dtype
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# # DataFrames and Python Built-Ins Functions

# %%
type(titanic)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
len(titanic)
# Out:
# 891

# %% [markdown]
# # DataFrame Attributes

# %%
titanic.shape #Number of rows and columns
# Out:
# (891, 9)

# %%
titanic.size #Number of items ie rows * columns
# Out:
# 8019

# %%
titanic.index #Number of indexes
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns #Column names
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic.head(2) #Show two rows
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C

# %%
titanic.min() #Show min of each column
# Out:
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare             0
# dtype: object

# %% [markdown]
# # Methods Chaining

# %%
titanic.mean().sort_values()
# Out:
# parch        0.381594
# survived     0.383838
# sibsp        0.523008
# pclass       2.308642
# age         29.699118
# fare        32.204208
# dtype: float64

# %%
titanic.sort_values(by = ['age'], ascending=False, kind='mergesort')
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 630         1       1    male  80.00      0      0   30.0000        S    A
# 851         0       3    male  74.00      0      0    7.7750        S  NaN
# 96          0       1    male  71.00      0      0   34.6542        C    A
# 493         0       1    male  71.00      0      0   49.5042        C  NaN
# 116         0       3    male  70.50      0      0    7.7500        Q  NaN
# 672         0       2    male  70.00      0      0   10.5000        S  NaN
# 745         0       1    male  70.00      1      1   71.0000        S    B
# 33          0       2    male  66.00      0      0   10.5000        S  NaN
# 54          0       1    male  65.00      0      1   61.9792        C    B
# 280         0       3    male  65.00      0      0    7.7500        Q  NaN
# 456         0       1    male  65.00      0      0   26.5500        S    E
# ...

# %%
titanic.sort_values(by = ['fare'], ascending=False, kind='mergesort')
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 258         1       1  female  35.00      0      0  512.3292        C  NaN
# 679         1       1    male  36.00      0      1  512.3292        C    B
# 737         1       1    male  35.00      0      0  512.3292        C    B
# 27          0       1    male  19.00      3      2  263.0000        S    C
# 88          1       1  female  23.00      3      2  263.0000        S    C
# 341         1       1  female  24.00      3      2  263.0000        S    C
# 438         0       1    male  64.00      1      4  263.0000        S    C
# 311         1       1  female  18.00      2      2  262.3750        C    B
# 742         1       1  female  21.00      2      2  262.3750        C    B
# 118         0       1    male  24.00      0      1  247.5208        C    B
# 299         1       1  female  50.00      0      1  247.5208        C    B
# ...

# %% [markdown]
# # Selecting Columns

# %%
titanic["age"] #Select single column - age
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
# 5        NaN
# 6      54.00
# 7       2.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 12     20.00
# 13     39.00
# 14     14.00
# 15     55.00
# 16      2.00
# 17       NaN
# 18     31.00
# 19       NaN
# 20     35.00
# 21     34.00
# 22     15.00
# 23     28.00
# 24      8.00
# 25     38.00
# 26       NaN
# 27     19.00
# 28       NaN
# 29       NaN
# 30     40.00
# 31       NaN
# 32       NaN
# 33     66.00
# 34     28.00
# 35     42.00
# 36       NaN
# 37     21.00
# 38     18.00
# 39     14.00
# 40     40.00
# 41     27.00
# 42       NaN
# 43      3.00
# 44     19.00
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49     18.00
# 50      7.00
# 51     21.00
# 52     49.00
# 53     29.00
# 54     65.00
# 55       NaN
# 56     21.00
# 57     28.50
# 58      5.00
# 59     11.00
# 60     22.00
# 61     38.00
# 62     45.00
# 63      4.00
# 64       NaN
# 65       NaN
# ...

# %%
titanic[["age", "sex"]] #Select 2 or more columns . NB Pass the column names as list
# Out:
#        age     sex
# 0    22.00    male
# 1    38.00  female
# 2    26.00  female
# 3    35.00  female
# 4    35.00    male
# 5      NaN    male
# 6    54.00    male
# 7     2.00    male
# 8    27.00  female
# 9    14.00  female
# 10    4.00  female
# 11   58.00  female
# 12   20.00    male
# 13   39.00    male
# 14   14.00  female
# 15   55.00  female
# 16    2.00    male
# 17     NaN    male
# 18   31.00  female
# 19     NaN  female
# 20   35.00    male
# 21   34.00    male
# 22   15.00  female
# 23   28.00    male
# 24    8.00  female
# 25   38.00  female
# 26     NaN    male
# 27   19.00    male
# 28     NaN  female
# 29     NaN    male
# 30   40.00    male
# 31     NaN  female
# 32     NaN  female
# 33   66.00    male
# 34   28.00    male
# 35   42.00    male
# 36     NaN    male
# 37   21.00    male
# 38   18.00  female
# 39   14.00  female
# 40   40.00  female
# 41   27.00  female
# 42     NaN    male
# 43    3.00  female
# 44   19.00  female
# 45     NaN    male
# ...

# %%
male_vs_female = titanic["sex"]

# %%
Counter(male_vs_female)
# Out:
# Counter({'male': 577, 'female': 314})

# %%
titanic[["age", "sex", "fare"]]
# Out:
#        age     sex      fare
# 0    22.00    male    7.2500
# 1    38.00  female   71.2833
# 2    26.00  female    7.9250
# 3    35.00  female   53.1000
# 4    35.00    male    8.0500
# 5      NaN    male    8.4583
# 6    54.00    male   51.8625
# 7     2.00    male   21.0750
# 8    27.00  female   11.1333
# 9    14.00  female   30.0708
# 10    4.00  female   16.7000
# 11   58.00  female   26.5500
# 12   20.00    male    8.0500
# 13   39.00    male   31.2750
# 14   14.00  female    7.8542
# 15   55.00  female   16.0000
# 16    2.00    male   29.1250
# 17     NaN    male   13.0000
# 18   31.00  female   18.0000
# 19     NaN  female    7.2250
# 20   35.00    male   26.0000
# 21   34.00    male   13.0000
# 22   15.00  female    8.0292
# 23   28.00    male   35.5000
# 24    8.00  female   21.0750
# 25   38.00  female   31.3875
# 26     NaN    male    7.2250
# 27   19.00    male  263.0000
# 28     NaN  female    7.8792
# 29     NaN    male    7.8958
# 30   40.00    male   27.7208
# ...

# %%
total_fare = titanic["fare"].sum()

# %%
total_fare
# Out:
# 28693.9493
