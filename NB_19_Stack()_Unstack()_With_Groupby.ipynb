# %%
import pandas as pd

# %%
summer = pd.read_csv("Data1/Course_Material_Part2/Video_Lecture_NBs/summer.csv")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
medal_by_country = summer.groupby(["Country", "Medal"]).Medal.count()

# %%
medal_by_country
# Out:
# Country  Medal
# AFG      Bronze     2
# AHO      Silver     1
# ALG      Bronze     8
#          Gold       5
#          Silver     2
#                    ..
# ZIM      Gold      18
#          Silver     4
# ZZX      Bronze    10
#          Gold      23
#          Silver    15
# Name: Medal, Length: 347, dtype: int64

# %%
type(medal_by_country)
# Out:
# pandas.core.series.Series

# %%
medal_by_country.loc["USA"]
# Out:
# Medal
# Bronze    1098
# Gold      2235
# Silver    1252
# Name: Medal, dtype: int64

# %%
medal_by_country.index #Notice it is a multi-index
# Out:
# MultiIndex([('AFG', 'Bronze'),
#             ('AHO', 'Silver'),
#             ('ALG', 'Bronze'),
#             ('ALG',   'Gold'),
#             ('ALG', 'Silver'),
#             ('ANZ', 'Bronze'),
#             ('ANZ',   'Gold'),
#             ('ANZ', 'Silver'),
#             ('ARG', 'Bronze'),
#             ('ARG',   'Gold'),
#             ...
#             ('YUG',   'Gold'),
#             ('YUG', 'Silver'),
#             ('ZAM', 'Bronze'),
#             ('ZAM', 'Silver'),
#             ('ZIM', 'Bronze'),
#             ('ZIM',   'Gold'),
#             ('ZIM', 'Silver'),
#             ('ZZX', 'Bronze'),
#             ('ZZX',   'Gold'),
#             ('ZZX', 'Silver')],
#            names=['Country', 'Medal'], length=347)

# %%
medal_by_country.loc[("USA", "Gold")]
# Out:
# 2235

# %%
medal_by_country.unstack()
# Out:
# Medal    Bronze   Gold  Silver
# Country
# AFG         2.0    NaN     NaN
# AHO         NaN    NaN     1.0
# ALG         8.0    5.0     2.0
# ANZ         5.0   20.0     4.0
# ARG        91.0   69.0    99.0
# ...         ...    ...     ...
# VIE         NaN    NaN     2.0
# YUG       118.0  143.0   174.0
# ZAM         1.0    NaN     1.0
# ZIM         1.0   18.0     4.0
# ZZX        10.0   23.0    15.0
#
# [147 rows x 3 columns]

# %%
medal_by_country.unstack(level=-1)
# Out:
# Medal    Bronze   Gold  Silver
# Country
# AFG         2.0    NaN     NaN
# AHO         NaN    NaN     1.0
# ALG         8.0    5.0     2.0
# ANZ         5.0   20.0     4.0
# ARG        91.0   69.0    99.0
# ...         ...    ...     ...
# VIE         NaN    NaN     2.0
# YUG       118.0  143.0   174.0
# ZAM         1.0    NaN     1.0
# ZIM         1.0   18.0     4.0
# ZZX        10.0   23.0    15.0
#
# [147 rows x 3 columns]

# %%
medal_by_country.unstack(level=-2)
# Out:
# Country  AFG  AHO  ALG   ANZ   ARG  ARM    AUS   AUT   AZE   BAH  ...    URS  \
# Medal                                                             ...
# Bronze   2.0  NaN  8.0   5.0  91.0  8.0  472.0  44.0  15.0   5.0  ...  584.0
# Gold     NaN  NaN  5.0  20.0  69.0  1.0  312.0  21.0   6.0  13.0  ...  838.0
# Silver   NaN  1.0  2.0   4.0  99.0  2.0  405.0  81.0   5.0   9.0  ...  627.0
#
# Country   URU     USA   UZB  VEN  VIE    YUG  ZAM   ZIM   ZZX
# Medal
# Bronze   30.0  1098.0  10.0  8.0  NaN  118.0  1.0   1.0  10.0
# Gold     44.0  2235.0   5.0  2.0  NaN  143.0  NaN  18.0  23.0
# Silver    2.0  1252.0   5.0  2.0  2.0  174.0  1.0   4.0  15.0
#
# [3 rows x 147 columns]

# %%
medal_by_country = medal_by_country.unstack(level=-1, fill_value=0)

# %%
medal_by_country
# Out:
# Country  AFG  AHO  ALG  ANZ  ARG  ARM  AUS  AUT  AZE  BAH  ...  URS  URU  \
# Medal                                                      ...
# Bronze     2    0    8    5   91    8  472   44   15    5  ...  584   30
# Gold       0    0    5   20   69    1  312   21    6   13  ...  838   44
# Silver     0    1    2    4   99    2  405   81    5    9  ...  627    2
#
# Country   USA  UZB  VEN  VIE  YUG  ZAM  ZIM  ZZX
# Medal
# Bronze   1098   10    8    0  118    1    1   10
# Gold     2235    5    2    0  143    0   18   23
# Silver   1252    5    2    2  174    1    4   15
#
# [3 rows x 147 columns]

# %%
medal_by_country.shape
# Out:
# (3, 147)

# %%
type(medal_by_country)
# Out:
# pandas.core.frame.DataFrame

# %%
medal_by_country = summer.groupby(["Country", "Medal"]).Medal.count()

# %%
medal_by_country
# Out:
# Country  Medal
# AFG      Bronze     2
# AHO      Silver     1
# ALG      Bronze     8
#          Gold       5
#          Silver     2
#                    ..
# ZIM      Gold      18
#          Silver     4
# ZZX      Bronze    10
#          Gold      23
#          Silver    15
# Name: Medal, Length: 347, dtype: int64

# %%
medal_by_country.shape
# Out:
# (347,)

# %%
medal_by_country = medal_by_country.unstack(level=-1, fill_value=0)

# %%
medal_by_country
# Out:
# Medal    Bronze  Gold  Silver
# Country
# AFG           2     0       0
# AHO           0     0       1
# ALG           8     5       2
# ANZ           5    20       4
# ARG          91    69      99
# ...         ...   ...     ...
# VIE           0     0       2
# YUG         118   143     174
# ZAM           1     0       1
# ZIM           1    18       4
# ZZX          10    23      15
#
# [147 rows x 3 columns]

# %%
medal_by_country.shape
# Out:
# (147, 3)

# %%
type(medal_by_country)
# Out:
# pandas.core.frame.DataFrame

# %%
medal_by_country.sort_values(["Gold", "Silver", "Bronze"], ascending=[False, False, False], inplace=True)

# %%
medal_by_country
# Out:
# Medal    Bronze  Gold  Silver
# Country
# USA        1098  2235    1252
# URS         584   838     627
# GBR         553   546     621
# ITA         404   476     416
# GER         475   452     378
# ...         ...   ...     ...
# IRQ           1     0       0
# MKD           1     0       0
# MRI           1     0       0
# NIG           1     0       0
# TOG           1     0       0
#
# [147 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
medal_by_country.head(10).plot(kind="bar", figsize=(12,8), fontsize=15)
plt.xlabel("Country", fontsize=13)
plt.ylabel("Medals", fontsize=13)
plt.title("Medals Per Country", fontsize=15)
plt.show()

# %%
medal_by_country.stack().unstack()
# Out:
# Medal    Bronze  Gold  Silver
# Country
# USA        1098  2235    1252
# URS         584   838     627
# GBR         553   546     621
# ITA         404   476     416
# GER         475   452     378
# ...         ...   ...     ...
# IRQ           1     0       0
# MKD           1     0       0
# MRI           1     0       0
# NIG           1     0       0
# TOG           1     0       0
#
# [147 rows x 3 columns]
